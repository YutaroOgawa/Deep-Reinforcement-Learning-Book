# %% [markdown]
# ## 3.4 CartPoleをQ学習で制御

# %%
# パッケージのimport
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 動画の描画関数の宣言
# 参考URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole.mp4')  # 動画のファイル名と保存です
    display(display_animation(anim, default_mode='loop'))

# %%
# 定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
NUM_DIZITIZED = 6  # 各状態の離散値への分割数
GAMMA = 0.99  # 時間割引率
ETA = 0.5  # 学習係数
MAX_STEPS = 200  # 1試行のstep数
NUM_EPISODES = 1000  # 最大試行回数

# %%
class Agent:
    '''CartPoleのエージェントクラスです、棒付き台車そのものになります'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q関数の更新'''
        self.brain.update_Q_table(
            observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''行動の決定'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''エージェントが持つ脳となるクラスです、Q学習を実行します'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # Qテーブルを作成。行数は状態を分割数^（4変数）にデジタル変換した値、列数は行動数を示す
        self.q_table = np.random.uniform(low=0, high=1, size=(
            NUM_DIZITIZED**num_states, num_actions))


    def bins(self, clip_min, clip_max, num):
        '''観測した状態（連続値）を離散値にデジタル変換する閾値を求める'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''観測したobservation状態を、離散値に変換する'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

    def update_Q_table(self, observation, action, reward, observation_next):
        '''QテーブルをQ学習により更新'''
        state = self.digitize_state(observation)  # 状態を離散化
        state_next = self.digitize_state(observation_next)  # 次の状態を離散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])

    def decide_action(self, observation, episode):
        '''ε-greedy法で徐々に最適行動のみを採用する'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 0,1の行動をランダムに返す
        return action

# %%
class Environment:
    '''CartPoleを実行する環境のクラスです'''

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態の数4を取得
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        self.agent = Agent(num_states, num_actions)  # 環境内で行動するAgentを生成

    def run(self):
        '''実行'''
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        is_episode_final = False  # 最終試行フラグ
        frames = []  # 動画用に画像を格納する変数

        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            for step in range(MAX_STEPS):  # 1エピソードのループ

                if is_episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))

                # 行動を求める
                action = self.agent.get_action(observation, episode)

                # 行動a_tの実行により、s_{t+1}, r_{t+1}を求める
                observation_next, _, done, _ = self.env.step(
                    action)  # rewardとinfoは使わないので_にする

                # 報酬を与える
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    if step < 195:
                        reward = -1  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 195step以上連続で立ち続けた試行数をリセット
                    else:
                        reward = 1  # 立ったまま終了時は報酬1を与える
                        complete_episodes += 1  # 連続記録を更新
                else:
                    reward = 0  # 途中の報酬は0

                # step+1の状態observation_nextを用いて,Q関数を更新する
                self.agent.update_Q_function(
                    observation, action, reward, observation_next)

                # 観測の更新
                observation = observation_next

                # 終了時の処理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(
                        episode, step + 1))
                    break

            if is_episode_final is True:  # 最終試行では動画を保存と描画
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:  # 10連続成功なら
                print('10回連続成功')
                is_episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# 0 Episode: Finished after 22 time steps
# 1 Episode: Finished after 27 time steps
# 2 Episode: Finished after 12 time steps
# 3 Episode: Finished after 17 time steps
# 4 Episode: Finished after 15 time steps
# 5 Episode: Finished after 10 time steps
# 6 Episode: Finished after 15 time steps
# 7 Episode: Finished after 8 time steps
# 8 Episode: Finished after 23 time steps
# 9 Episode: Finished after 43 time steps
# 10 Episode: Finished after 11 time steps
# 11 Episode: Finished after 20 time steps
# 12 Episode: Finished after 12 time steps
# 13 Episode: Finished after 16 time steps
# 14 Episode: Finished after 14 time steps
# 15 Episode: Finished after 10 time steps
# 16 Episode: Finished after 18 time steps
# 17 Episode: Finished after 12 time steps
# 18 Episode: Finished after 11 time steps
# 19 Episode: Finished after 31 time steps
# 20 Episode: Finished after 13 time steps
# 21 Episode: Finished after 13 time steps
# 22 Episode: Finished after 34 time steps
# 23 Episode: Finished after 11 time steps
# 24 Episode: Finished after 8 time steps
# 25 Episode: Finished after 25 time steps
# 26 Episode: Finished after 16 time steps
# 27 Episode: Finished after 12 time steps
# 28 Episode: Finished after 23 time steps
# 29 Episode: Finished after 17 time steps
# 30 Episode: Finished after 13 time steps
# 31 Episode: Finished after 78 time steps
# 32 Episode: Finished after 17 time steps
# 33 Episode: Finished after 15 time steps
# 34 Episode: Finished after 141 time steps
# 35 Episode: Finished after 50 time steps
# 36 Episode: Finished after 61 time steps
# 37 Episode: Finished after 192 time steps
# 38 Episode: Finished after 200 time steps
# 39 Episode: Finished after 22 time steps
# 40 Episode: Finished after 165 time steps
# 41 Episode: Finished after 21 time steps
# 42 Episode: Finished after 15 time steps
# 43 Episode: Finished after 65 time steps
# 44 Episode: Finished after 102 time steps
# 45 Episode: Finished after 49 time steps
# 46 Episode: Finished after 86 time steps
# 47 Episode: Finished after 160 time steps
# 48 Episode: Finished after 19 time steps
# 49 Episode: Finished after 21 time steps
# 50 Episode: Finished after 26 time steps
# 51 Episode: Finished after 26 time steps
# 52 Episode: Finished after 115 time steps
# 53 Episode: Finished after 63 time steps
# 54 Episode: Finished after 82 time steps
# 55 Episode: Finished after 23 time steps
# 56 Episode: Finished after 24 time steps
# 57 Episode: Finished after 27 time steps
# 58 Episode: Finished after 140 time steps
# 59 Episode: Finished after 123 time steps
# 60 Episode: Finished after 34 time steps
# 61 Episode: Finished after 63 time steps
# 62 Episode: Finished after 176 time steps
# 63 Episode: Finished after 200 time steps
# 64 Episode: Finished after 70 time steps
# 65 Episode: Finished after 14 time steps
# 66 Episode: Finished after 156 time steps
# 67 Episode: Finished after 183 time steps
# 68 Episode: Finished after 129 time steps
# 69 Episode: Finished after 16 time steps
# 70 Episode: Finished after 9 time steps
# 71 Episode: Finished after 43 time steps
# 72 Episode: Finished after 22 time steps
# 73 Episode: Finished after 108 time steps
# 74 Episode: Finished after 15 time steps
# 75 Episode: Finished after 60 time steps
# 76 Episode: Finished after 10 time steps
# 77 Episode: Finished after 71 time steps
# 78 Episode: Finished after 26 time steps
# 79 Episode: Finished after 45 time steps
# 80 Episode: Finished after 32 time steps
# 81 Episode: Finished after 60 time steps
# 82 Episode: Finished after 65 time steps
# 83 Episode: Finished after 88 time steps
# 84 Episode: Finished after 67 time steps
# 85 Episode: Finished after 67 time steps
# 86 Episode: Finished after 46 time steps
# 87 Episode: Finished after 69 time steps
# 88 Episode: Finished after 31 time steps
# 89 Episode: Finished after 200 time steps
# 90 Episode: Finished after 57 time steps
# 91 Episode: Finished after 200 time steps
# 92 Episode: Finished after 138 time steps
# 93 Episode: Finished after 131 time steps
# 94 Episode: Finished after 98 time steps
# 95 Episode: Finished after 112 time steps
# 96 Episode: Finished after 146 time steps
# 97 Episode: Finished after 200 time steps
# 98 Episode: Finished after 200 time steps
# 99 Episode: Finished after 129 time steps
# 100 Episode: Finished after 124 time steps
# 101 Episode: Finished after 174 time steps
# 102 Episode: Finished after 200 time steps
# 103 Episode: Finished after 200 time steps
# 104 Episode: Finished after 200 time steps
# 105 Episode: Finished after 69 time steps
# 106 Episode: Finished after 200 time steps
# 107 Episode: Finished after 200 time steps
# 108 Episode: Finished after 108 time steps
# 109 Episode: Finished after 16 time steps
# 110 Episode: Finished after 23 time steps
# 111 Episode: Finished after 115 time steps
# 112 Episode: Finished after 45 time steps
# 113 Episode: Finished after 85 time steps
# 114 Episode: Finished after 174 time steps
# 115 Episode: Finished after 28 time steps
# 116 Episode: Finished after 73 time steps
# 117 Episode: Finished after 40 time steps
# 118 Episode: Finished after 35 time steps
# 119 Episode: Finished after 45 time steps
# 120 Episode: Finished after 158 time steps
# 121 Episode: Finished after 67 time steps
# 122 Episode: Finished after 148 time steps
# 123 Episode: Finished after 95 time steps
# 124 Episode: Finished after 33 time steps
# 125 Episode: Finished after 134 time steps
# 126 Episode: Finished after 52 time steps
# 127 Episode: Finished after 197 time steps
# 128 Episode: Finished after 150 time steps
# 129 Episode: Finished after 200 time steps
# 130 Episode: Finished after 150 time steps
# 131 Episode: Finished after 96 time steps
# 132 Episode: Finished after 31 time steps
# 133 Episode: Finished after 200 time steps
# 134 Episode: Finished after 185 time steps
# 135 Episode: Finished after 142 time steps
# 136 Episode: Finished after 165 time steps
# 137 Episode: Finished after 200 time steps
# 138 Episode: Finished after 197 time steps
# 139 Episode: Finished after 150 time steps
# 140 Episode: Finished after 50 time steps
# 141 Episode: Finished after 200 time steps
# 142 Episode: Finished after 200 time steps
# 143 Episode: Finished after 133 time steps
# 144 Episode: Finished after 156 time steps
# 145 Episode: Finished after 101 time steps
# 146 Episode: Finished after 176 time steps
# 147 Episode: Finished after 184 time steps
# 148 Episode: Finished after 196 time steps
# 149 Episode: Finished after 166 time steps
# 150 Episode: Finished after 98 time steps
# 151 Episode: Finished after 200 time steps
# 152 Episode: Finished after 33 time steps
# 153 Episode: Finished after 117 time steps
# 154 Episode: Finished after 81 time steps
# 155 Episode: Finished after 139 time steps
# 156 Episode: Finished after 200 time steps
# 157 Episode: Finished after 178 time steps
# 158 Episode: Finished after 22 time steps
# 159 Episode: Finished after 200 time steps
# 160 Episode: Finished after 200 time steps
# 161 Episode: Finished after 138 time steps
# 162 Episode: Finished after 32 time steps
# 163 Episode: Finished after 144 time steps
# 164 Episode: Finished after 200 time steps
# 165 Episode: Finished after 200 time steps
# 166 Episode: Finished after 200 time steps
# 167 Episode: Finished after 200 time steps
# 168 Episode: Finished after 200 time steps
# 169 Episode: Finished after 200 time steps
# 170 Episode: Finished after 200 time steps
# 171 Episode: Finished after 200 time steps
# 172 Episode: Finished after 200 time steps
# 173 Episode: Finished after 120 time steps
# 174 Episode: Finished after 200 time steps
# 175 Episode: Finished after 200 time steps
# 176 Episode: Finished after 133 time steps
# 177 Episode: Finished after 183 time steps
# 178 Episode: Finished after 200 time steps
# 179 Episode: Finished after 168 time steps
# 180 Episode: Finished after 171 time steps
# 181 Episode: Finished after 200 time steps
# 182 Episode: Finished after 120 time steps
# 183 Episode: Finished after 105 time steps
# 184 Episode: Finished after 181 time steps
# 185 Episode: Finished after 105 time steps
# 186 Episode: Finished after 178 time steps
# 187 Episode: Finished after 137 time steps
# 188 Episode: Finished after 94 time steps
# 189 Episode: Finished after 153 time steps
# 190 Episode: Finished after 107 time steps
# 191 Episode: Finished after 120 time steps
# 192 Episode: Finished after 122 time steps
# 193 Episode: Finished after 125 time steps
# 194 Episode: Finished after 148 time steps
# 195 Episode: Finished after 200 time steps
# 196 Episode: Finished after 86 time steps
# 197 Episode: Finished after 132 time steps
# 198 Episode: Finished after 139 time steps
# 199 Episode: Finished after 200 time steps
# 200 Episode: Finished after 163 time steps
# 201 Episode: Finished after 168 time steps
# 202 Episode: Finished after 200 time steps
# 203 Episode: Finished after 200 time steps
# 204 Episode: Finished after 166 time steps
# 205 Episode: Finished after 200 time steps
# 206 Episode: Finished after 200 time steps
# 207 Episode: Finished after 191 time steps
# 208 Episode: Finished after 101 time steps
# 209 Episode: Finished after 200 time steps
# 210 Episode: Finished after 100 time steps
# 211 Episode: Finished after 159 time steps
# 212 Episode: Finished after 200 time steps
# 213 Episode: Finished after 144 time steps
# 214 Episode: Finished after 200 time steps
# 215 Episode: Finished after 200 time steps
# 216 Episode: Finished after 172 time steps
# 217 Episode: Finished after 194 time steps
# 218 Episode: Finished after 200 time steps
# 219 Episode: Finished after 172 time steps
# 220 Episode: Finished after 193 time steps
# 221 Episode: Finished after 193 time steps
# 222 Episode: Finished after 200 time steps
# 223 Episode: Finished after 151 time steps
# 224 Episode: Finished after 200 time steps
# 225 Episode: Finished after 125 time steps
# 226 Episode: Finished after 149 time steps
# 227 Episode: Finished after 200 time steps
# 228 Episode: Finished after 187 time steps
# 229 Episode: Finished after 69 time steps
# 230 Episode: Finished after 151 time steps
# 231 Episode: Finished after 77 time steps
# 232 Episode: Finished after 141 time steps
# 233 Episode: Finished after 200 time steps
# 234 Episode: Finished after 139 time steps
# 235 Episode: Finished after 200 time steps
# 236 Episode: Finished after 200 time steps
# 237 Episode: Finished after 136 time steps
# 238 Episode: Finished after 145 time steps
# 239 Episode: Finished after 48 time steps
# 240 Episode: Finished after 86 time steps
# 241 Episode: Finished after 174 time steps
# 242 Episode: Finished after 127 time steps
# 243 Episode: Finished after 200 time steps
# 244 Episode: Finished after 56 time steps
# 245 Episode: Finished after 148 time steps
# 246 Episode: Finished after 160 time steps
# 247 Episode: Finished after 57 time steps
# 248 Episode: Finished after 190 time steps
# 249 Episode: Finished after 133 time steps
# 250 Episode: Finished after 110 time steps
# 251 Episode: Finished after 119 time steps
# 252 Episode: Finished after 133 time steps
# 253 Episode: Finished after 115 time steps
# 254 Episode: Finished after 99 time steps
# 255 Episode: Finished after 68 time steps
# 256 Episode: Finished after 35 time steps
# 257 Episode: Finished after 29 time steps
# 258 Episode: Finished after 200 time steps
# 259 Episode: Finished after 158 time steps
# 260 Episode: Finished after 200 time steps
# 261 Episode: Finished after 195 time steps
# 262 Episode: Finished after 200 time steps
# 263 Episode: Finished after 96 time steps
# 264 Episode: Finished after 146 time steps
# 265 Episode: Finished after 137 time steps
# 266 Episode: Finished after 139 time steps
# 267 Episode: Finished after 103 time steps
# 268 Episode: Finished after 175 time steps
# 269 Episode: Finished after 200 time steps
# 270 Episode: Finished after 162 time steps
# 271 Episode: Finished after 139 time steps
# 272 Episode: Finished after 200 time steps
# 273 Episode: Finished after 200 time steps
# 274 Episode: Finished after 190 time steps
# 275 Episode: Finished after 117 time steps
# 276 Episode: Finished after 114 time steps
# 277 Episode: Finished after 40 time steps
# 278 Episode: Finished after 19 time steps
# 279 Episode: Finished after 167 time steps
# 280 Episode: Finished after 125 time steps
# 281 Episode: Finished after 119 time steps
# 282 Episode: Finished after 95 time steps
# 283 Episode: Finished after 200 time steps
# 284 Episode: Finished after 181 time steps
# 285 Episode: Finished after 29 time steps
# 286 Episode: Finished after 165 time steps
# 287 Episode: Finished after 192 time steps
# 288 Episode: Finished after 200 time steps
# 289 Episode: Finished after 137 time steps
# 290 Episode: Finished after 200 time steps
# 291 Episode: Finished after 84 time steps
# 292 Episode: Finished after 200 time steps
# 293 Episode: Finished after 157 time steps
# 294 Episode: Finished after 196 time steps
# 295 Episode: Finished after 200 time steps
# 296 Episode: Finished after 29 time steps
# 297 Episode: Finished after 200 time steps
# 298 Episode: Finished after 200 time steps
# 299 Episode: Finished after 200 time steps
# 300 Episode: Finished after 200 time steps
# 301 Episode: Finished after 200 time steps
# 302 Episode: Finished after 200 time steps
# 303 Episode: Finished after 172 time steps
# 304 Episode: Finished after 151 time steps
# 305 Episode: Finished after 35 time steps
# 306 Episode: Finished after 58 time steps
# 307 Episode: Finished after 27 time steps
# 308 Episode: Finished after 8 time steps
# 309 Episode: Finished after 37 time steps
# 310 Episode: Finished after 35 time steps
# 311 Episode: Finished after 200 time steps
# 312 Episode: Finished after 181 time steps
# 313 Episode: Finished after 200 time steps
# 314 Episode: Finished after 200 time steps
# 315 Episode: Finished after 200 time steps
# 316 Episode: Finished after 200 time steps
# 317 Episode: Finished after 24 time steps
# 318 Episode: Finished after 200 time steps
# 319 Episode: Finished after 200 time steps
# 320 Episode: Finished after 200 time steps
# 321 Episode: Finished after 200 time steps
# 322 Episode: Finished after 200 time steps
# 323 Episode: Finished after 200 time steps
# 324 Episode: Finished after 200 time steps
# 325 Episode: Finished after 200 time steps
# 326 Episode: Finished after 57 time steps
# 327 Episode: Finished after 162 time steps
# 328 Episode: Finished after 199 time steps
# 329 Episode: Finished after 71 time steps
# 330 Episode: Finished after 200 time steps
# 331 Episode: Finished after 200 time steps
# 332 Episode: Finished after 156 time steps
# 333 Episode: Finished after 61 time steps
# 334 Episode: Finished after 196 time steps
# 335 Episode: Finished after 200 time steps
# 336 Episode: Finished after 200 time steps
# 337 Episode: Finished after 194 time steps
# 338 Episode: Finished after 200 time steps
# 339 Episode: Finished after 73 time steps
# 340 Episode: Finished after 200 time steps
# 341 Episode: Finished after 56 time steps
# 342 Episode: Finished after 200 time steps
# 343 Episode: Finished after 200 time steps
# 344 Episode: Finished after 187 time steps
# 345 Episode: Finished after 200 time steps
# 346 Episode: Finished after 29 time steps
# 347 Episode: Finished after 200 time steps
# 348 Episode: Finished after 200 time steps
# 349 Episode: Finished after 200 time steps
# 350 Episode: Finished after 200 time steps
# 351 Episode: Finished after 200 time steps
# 352 Episode: Finished after 200 time steps
# 353 Episode: Finished after 200 time steps
# 354 Episode: Finished after 200 time steps
# 355 Episode: Finished after 93 time steps
# 356 Episode: Finished after 200 time steps
# 357 Episode: Finished after 200 time steps
# 358 Episode: Finished after 191 time steps
# 359 Episode: Finished after 69 time steps
# 360 Episode: Finished after 182 time steps
# 361 Episode: Finished after 36 time steps
# 362 Episode: Finished after 200 time steps
# 363 Episode: Finished after 200 time steps
# 364 Episode: Finished after 192 time steps
# 365 Episode: Finished after 198 time steps
# 366 Episode: Finished after 200 time steps
# 367 Episode: Finished after 200 time steps
# 368 Episode: Finished after 63 time steps
# 369 Episode: Finished after 200 time steps
# 370 Episode: Finished after 164 time steps
# 371 Episode: Finished after 108 time steps
# 372 Episode: Finished after 77 time steps
# 373 Episode: Finished after 200 time steps
# 374 Episode: Finished after 200 time steps
# 375 Episode: Finished after 200 time steps
# 376 Episode: Finished after 161 time steps
# 377 Episode: Finished after 200 time steps
# 378 Episode: Finished after 200 time steps
# 379 Episode: Finished after 89 time steps
# 380 Episode: Finished after 195 time steps
# 381 Episode: Finished after 200 time steps
# 382 Episode: Finished after 200 time steps
# 383 Episode: Finished after 45 time steps
# 384 Episode: Finished after 200 time steps
# 385 Episode: Finished after 101 time steps
# 386 Episode: Finished after 200 time steps
# 387 Episode: Finished after 200 time steps
# 388 Episode: Finished after 200 time steps
# 389 Episode: Finished after 36 time steps
# 390 Episode: Finished after 102 time steps
# 391 Episode: Finished after 200 time steps
# 392 Episode: Finished after 200 time steps
# 393 Episode: Finished after 200 time steps
# 394 Episode: Finished after 130 time steps
# 395 Episode: Finished after 113 time steps
# 396 Episode: Finished after 154 time steps
# 397 Episode: Finished after 193 time steps
# 398 Episode: Finished after 200 time steps
# 399 Episode: Finished after 177 time steps
# 400 Episode: Finished after 118 time steps
# 401 Episode: Finished after 168 time steps
# 402 Episode: Finished after 200 time steps
# 403 Episode: Finished after 151 time steps
# 404 Episode: Finished after 200 time steps
# 405 Episode: Finished after 105 time steps
# 406 Episode: Finished after 200 time steps
# 407 Episode: Finished after 38 time steps
# 408 Episode: Finished after 149 time steps
# 409 Episode: Finished after 200 time steps
# 410 Episode: Finished after 110 time steps
# 411 Episode: Finished after 198 time steps
# 412 Episode: Finished after 200 time steps
# 413 Episode: Finished after 198 time steps
# 414 Episode: Finished after 197 time steps
# 415 Episode: Finished after 200 time steps
# 416 Episode: Finished after 193 time steps
# 417 Episode: Finished after 200 time steps
# 418 Episode: Finished after 200 time steps
# 419 Episode: Finished after 134 time steps
# 420 Episode: Finished after 200 time steps
# 421 Episode: Finished after 200 time steps
# 422 Episode: Finished after 156 time steps
# 423 Episode: Finished after 157 time steps
# 424 Episode: Finished after 200 time steps
# 425 Episode: Finished after 33 time steps
# 426 Episode: Finished after 200 time steps
# 427 Episode: Finished after 200 time steps
# 428 Episode: Finished after 22 time steps
# 429 Episode: Finished after 176 time steps
# 430 Episode: Finished after 200 time steps
# 431 Episode: Finished after 200 time steps
# 432 Episode: Finished after 168 time steps
# 433 Episode: Finished after 187 time steps
# 434 Episode: Finished after 200 time steps
# 435 Episode: Finished after 107 time steps
# 436 Episode: Finished after 111 time steps
# 437 Episode: Finished after 200 time steps
# 438 Episode: Finished after 200 time steps
# 439 Episode: Finished after 185 time steps
# 440 Episode: Finished after 200 time steps
# 441 Episode: Finished after 200 time steps
# 442 Episode: Finished after 138 time steps
# 443 Episode: Finished after 200 time steps
# 444 Episode: Finished after 163 time steps
# 445 Episode: Finished after 200 time steps
# 446 Episode: Finished after 200 time steps
# 447 Episode: Finished after 200 time steps
# 448 Episode: Finished after 160 time steps
# 449 Episode: Finished after 188 time steps
# 450 Episode: Finished after 103 time steps
# 451 Episode: Finished after 200 time steps
# 452 Episode: Finished after 200 time steps
# 453 Episode: Finished after 79 time steps
# 454 Episode: Finished after 200 time steps
# 455 Episode: Finished after 22 time steps
# 456 Episode: Finished after 200 time steps
# 457 Episode: Finished after 200 time steps
# 458 Episode: Finished after 200 time steps
# 459 Episode: Finished after 200 time steps
# 460 Episode: Finished after 200 time steps
# 461 Episode: Finished after 193 time steps
# 462 Episode: Finished after 200 time steps
# 463 Episode: Finished after 200 time steps
# 464 Episode: Finished after 200 time steps
# 465 Episode: Finished after 200 time steps
# 466 Episode: Finished after 200 time steps
# 467 Episode: Finished after 200 time steps
# 468 Episode: Finished after 200 time steps
# 469 Episode: Finished after 177 time steps
# 470 Episode: Finished after 200 time steps
# 471 Episode: Finished after 185 time steps
# 472 Episode: Finished after 200 time steps
# 473 Episode: Finished after 200 time steps
# 474 Episode: Finished after 131 time steps
# 475 Episode: Finished after 200 time steps
# 476 Episode: Finished after 200 time steps
# 477 Episode: Finished after 200 time steps
# 478 Episode: Finished after 200 time steps
# 479 Episode: Finished after 200 time steps
# 480 Episode: Finished after 200 time steps
# 481 Episode: Finished after 200 time steps
# 482 Episode: Finished after 169 time steps
# 483 Episode: Finished after 188 time steps
# 484 Episode: Finished after 200 time steps
# 485 Episode: Finished after 200 time steps
# 486 Episode: Finished after 200 time steps
# 487 Episode: Finished after 172 time steps
# 488 Episode: Finished after 167 time steps
# 489 Episode: Finished after 200 time steps
# 490 Episode: Finished after 200 time steps
# 491 Episode: Finished after 200 time steps
# 492 Episode: Finished after 200 time steps
# 493 Episode: Finished after 200 time steps
# 494 Episode: Finished after 200 time steps
# 495 Episode: Finished after 200 time steps
# 496 Episode: Finished after 200 time steps
# 497 Episode: Finished after 200 time steps
# 498 Episode: Finished after 200 time steps
# 10回連続成功
# 499 Episode: Finished after 200 time steps
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgTGHEMQVWAJRGKPBH">
#     <br>
#     <input id="_anim_sliderTGHEMQVWAJRGKPBH" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animTGHEMQVWAJRGKPBH.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animTGHEMQVWAJRGKPBH.slower()">&#8211;</button>
#     <button onclick="animTGHEMQVWAJRGKPBH.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animTGHEMQVWAJRGKPBH.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectTGHEMQVWAJRGKPBH" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgTGHEMQVWAJRGKPBH";
#     var slider_id = "_anim_sliderTGHEMQVWAJRGKPBH";
#     var loop_select_id = "_anim_loop_selectTGHEMQVWAJRGKPBH";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
